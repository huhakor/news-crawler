# %% [markdown]
# # Libraries

# %%
# import libraries
import warnings
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2

# path settings & modules importing
import sys
from pathlib import Path
import navernews as nn
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_folder = Path('data')

# naver의 경우 크롤링 중 중복 url 처리 로직으로 중복된 데이터 x
nn.analyze_all(data_folder)
# Out:
# 데이터 수집 결과: all
# year_month  total_count  dup_count  dedup_count
#     202210          105          2          103
#     202211           59          0           59
#     202212          148          0          148
#     202301          516        210          306
#     202302          656        272          384
#     202303          655        222          433
#     202304          528        202          326
#     202305          540        151          389
#     202306         4598       3510         1088
#     202307         1473        856          617
#     202308         1585        937          648
#     202309         1482        823          659
#     202310         4652       3637         1015
#     202311         2703       1794          909
#     202312          876        399          477
#     202401         1706        878          828
#     202402         2606       1728          878
#     202403         1661       1025          636
# ...

# %% [markdown]
# # Big Kinds
# ----
# - "AI 디지털교과서" 20221001~2025430 빅카인즈 뉴스 검색 결과

# %%
from IPython.display import Image, display
display(Image(filename='bigkinds.png', width=800))
